# %% [markdown]
# # This is a sample notebook
#
# This notebook combines both text, and code. Quite useful to share your codes.
#
# In this example we are going to generate some random data and do some simple plots.

# %%
# %pylab inline  # This is a magic function. Later we will come back to them

import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Generate random data
a = np.random.randn(100)

# Plot generated data
plt.plot(a)
plt.grid()
plt.show()
